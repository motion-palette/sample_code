# %%
para= """Carnegie Mellon University will open its largest building on campus on 
Thursday, Sept. 13, reflecting a new model of higher education that connects 
teaching, learning and innovation. The 315,000-square-foot David A. Tepper 
Quadrangle will serve as the new home of the Tepper School of Business while 
intersecting with the other six  Carnegie Mellon colleges and schools."""

words = para.split()

# def myfunction(words):
#     print(words)
    
# def myfunction(words):
#     for w in words: 
#         print(w)

# def myfunction(words):
#     prev_word = ""
#     for w in words:
#         print("{} {}".format(prev_word, w))
#         prev_word = w

# def myfunction(words):
#     prev_word = ""
#     for w in words:
#         if prev_word != "":
#             print("{} {}".format(prev_word, w))
#         prev_word = w

def myfunction(words):
    result_list = []
    prev_word = ""
    for w in words:
        if prev_word != "":
            result_list.append(prev_word + " " + w)
        prev_word = w

    return result_list

myfunction(para.split())
# Out:
# ['Carnegie Mellon',
#  'Mellon University',
#  'University will',
#  'will open',
#  'open its',
#  'its largest',
#  'largest building',
#  'building on',
#  'on campus',
#  'campus on',
#  'on Thursday,',
#  'Thursday, Sept.',
#  'Sept. 13,',
#  '13, reflecting',
#  'reflecting a',
#  'a new',
#  'new model',
#  'model of',
#  'of higher',
#  'higher education',
#  'education that',
#  'that connects',
#  'connects teaching,',
#  'teaching, learning',
#  'learning and',
#  'and innovation.',
#  'innovation. The',
#  'The 315,000-square-foot',
#  '315,000-square-foot David',
#  'David A.',
#  'A. Tepper',
#  'Tepper Quadrangle',
#  'Quadrangle will',
#  'will serve',
#  'serve as',
#  'as the',
#  'the new',
#  'new home',
#  'home of',
#  'of the',
#  'the Tepper',
#  'Tepper School',
#  'School of',
#  'of Business',
#  'Business while',
#  'while intersecting',
#  'intersecting with',
#  'with the',
#  'the other',
#  'other six',
#  'six Carnegie',
#  'Carnegie Mellon',
# ...
